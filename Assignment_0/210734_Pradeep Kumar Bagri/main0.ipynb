# %%
import numpy as np
import matplotlib.pyplot as plt
import nbimporter
from activation import *
from graph import *

# %%
a = [-100, -15, -9, -5, -1, 0, 1, 5 , 9, 15, 100]
z=np.array(a)

# %%
sigmoid(z)
# Out:
# array([3.72007598e-44, 3.05902227e-07, 1.23394576e-04, 6.69285092e-03,
#        2.68941421e-01, 5.00000000e-01, 7.31058579e-01, 9.93307149e-01,
#        9.99876605e-01, 9.99999694e-01, 1.00000000e+00])

# %%
tanh(z)
# Out:
# array([-1.        , -1.        , -0.99999997, -0.9999092 , -0.76159416,
#         0.        ,  0.76159416,  0.9999092 ,  0.99999997,  1.        ,
#         1.        ])

# %%
relu(z)
# Out:
# array([  0,   0,   0,   0,   0,   0,   1,   5,   9,  15, 100])

# %%
sigmoid_g(-10,10)

# %%
tanh_g(-10,10)

# %%
relu_g(-10,10)
