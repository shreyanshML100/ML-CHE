# %% [markdown]
# # SCATTER PLOT

# %%
import numpy as np
import matplotlib.pyplot as plt 
import linearRegression as ok

# %%
X_train = np.array([2.5, 4.7, 5.2, 7.3, 9.5, 11.5])
Y_train = np.array([5.21, 7.70, 8.30, 11, 14.5, 15])
plt.scatter(X_train,Y_train)
plt.show()

# %% [markdown]
# # L1 Regularization

# %%
X_train = np.matrix([2.5, 4.7, 5.2, 7.3, 9.5, 11.5])
X_train = np.transpose(X_train)
Y_train = np.matrix([5.21, 7.70, 8.30, 11, 14.5, 15])
Y_train = np.transpose(Y_train)
theta1 = ok.fitGD(X_train, Y_train, 0.01, 0.01, 1, 100)



y1 = np.arange(start=0.5,stop=11.5,step=1)
x1 = float(theta1)
x1 = x1*y1


plt.plot(y1,x1,color="red")
X_train = np.array([2.5, 4.7, 5.2, 7.3, 9.5, 11.5])
Y_train = np.array([5.21, 7.70, 8.30, 11, 14.5, 15])
plt.scatter(X_train,Y_train)

plt.show()
# Out:
# [0.80486667 1.16548718 1.3270632  1.39945733 1.43189352 1.44642656
#  1.45293809 1.45585558 1.45716276 1.45774844 1.45801086 1.45812843
#  1.45818111 1.45820471 1.45821529 1.45822003 1.45822215 1.4582231
#  1.45822353 1.45822372 1.4582238  1.45822384 1.45822386 1.45822387
#  1.45822387 1.45822387 1.45822387 1.45822387 1.45822387 1.45822387
#  1.45822387 1.45822387 1.45822387 1.45822387 1.45822387 1.45822387
#  1.45822387 1.45822387 1.45822387 1.45822387 1.45822387 1.45822387
#  1.45822387 1.45822387 1.45822387 1.45822387 1.45822387 1.45822387
#  1.45822387 1.45822387 1.45822387 1.45822387 1.45822387 1.45822387
#  1.45822387 1.45822387 1.45822387 1.45822387 1.45822387 1.45822387
#  1.45822387 1.45822387 1.45822387 1.45822387 1.45822387 1.45822387
#  1.45822387 1.45822387 1.45822387 1.45822387 1.45822387 1.45822387
#  1.45822387 1.45822387 1.45822387 1.45822387 1.45822387 1.45822387
#  1.45822387 1.45822387 1.45822387 1.45822387 1.45822387 1.45822387
#  1.45822387 1.45822387 1.45822387 1.45822387 1.45822387 1.45822387
#  1.45822387 1.45822387 1.45822387 1.45822387 1.45822387 1.45822387
#  1.45822387 1.45822387 1.45822387 1.45822387]

# %% [markdown]
# # L2 Regularization

# %%
X_train = np.matrix([2.5, 4.7, 5.2, 7.3, 9.5, 11.5])
X_train = np.transpose(X_train)
Y_train = np.matrix([5.21, 7.70, 8.30, 11, 14.5, 15])
Y_train = np.transpose(Y_train)
theta1 = ok.fitGD(X_train, Y_train, 0.01, 0.01, 2, 100)



y1 = np.arange(start=0.5,stop=11.5,step=1)
x1 = float(theta1)
x1 = x1*y1


plt.plot(y1,x1,color="red")
X_train = np.array([2.5, 4.7, 5.2, 7.3, 9.5, 11.5])
Y_train = np.array([5.21, 7.70, 8.30, 11, 14.5, 15])
plt.scatter(X_train,Y_train)

plt.show()
# Out:
# [0.804875   1.16548583 1.3270515  1.39943831 1.43187001 1.44640049
#  1.45291063 1.45582739 1.4571342  1.45771969 1.45798201 1.45809954
#  1.4581522  1.45817579 1.45818636 1.4581911  1.45819322 1.45819417
#  1.45819459 1.45819478 1.45819487 1.45819491 1.45819493 1.45819493
#  1.45819494 1.45819494 1.45819494 1.45819494 1.45819494 1.45819494
#  1.45819494 1.45819494 1.45819494 1.45819494 1.45819494 1.45819494
#  1.45819494 1.45819494 1.45819494 1.45819494 1.45819494 1.45819494
#  1.45819494 1.45819494 1.45819494 1.45819494 1.45819494 1.45819494
#  1.45819494 1.45819494 1.45819494 1.45819494 1.45819494 1.45819494
#  1.45819494 1.45819494 1.45819494 1.45819494 1.45819494 1.45819494
#  1.45819494 1.45819494 1.45819494 1.45819494 1.45819494 1.45819494
#  1.45819494 1.45819494 1.45819494 1.45819494 1.45819494 1.45819494
#  1.45819494 1.45819494 1.45819494 1.45819494 1.45819494 1.45819494
#  1.45819494 1.45819494 1.45819494 1.45819494 1.45819494 1.45819494
#  1.45819494 1.45819494 1.45819494 1.45819494 1.45819494 1.45819494
#  1.45819494 1.45819494 1.45819494 1.45819494 1.45819494 1.45819494
#  1.45819494 1.45819494 1.45819494 1.45819494]

# %% [markdown]
# # Elastic Regularization

# %%
X_train = np.matrix([2.5, 4.7, 5.2, 7.3, 9.5, 11.5])
X_train = np.transpose(X_train)
Y_train = np.matrix([5.21, 7.70, 8.30, 11, 14.5, 15])
Y_train = np.transpose(Y_train)
theta1 = ok.fitGD(X_train, Y_train, 0.01, 0.01, 3, 100)



y1 = np.arange(start=0.5,stop=11.5,step=1)
x1 = float(theta1)
x1 = x1*y1


plt.plot(y1,x1,color="red")
X_train = np.array([2.5, 4.7, 5.2, 7.3, 9.5, 11.5])
Y_train = np.array([5.21, 7.70, 8.30, 11, 14.5, 15])
plt.scatter(X_train,Y_train)

plt.show()
# Out:
# [0.80487083 1.1654865  1.32705735 1.39944782 1.43188177 1.44641353
#  1.45292436 1.45584149 1.45714848 1.45773407 1.45799643 1.45811399
#  1.45816665 1.45819025 1.45820082 1.45820556 1.45820768 1.45820863
#  1.45820906 1.45820925 1.45820934 1.45820937 1.45820939 1.4582094
#  1.4582094  1.4582094  1.45820941 1.45820941 1.45820941 1.45820941
#  1.45820941 1.45820941 1.45820941 1.45820941 1.45820941 1.45820941
#  1.45820941 1.45820941 1.45820941 1.45820941 1.45820941 1.45820941
#  1.45820941 1.45820941 1.45820941 1.45820941 1.45820941 1.45820941
#  1.45820941 1.45820941 1.45820941 1.45820941 1.45820941 1.45820941
#  1.45820941 1.45820941 1.45820941 1.45820941 1.45820941 1.45820941
#  1.45820941 1.45820941 1.45820941 1.45820941 1.45820941 1.45820941
#  1.45820941 1.45820941 1.45820941 1.45820941 1.45820941 1.45820941
#  1.45820941 1.45820941 1.45820941 1.45820941 1.45820941 1.45820941
#  1.45820941 1.45820941 1.45820941 1.45820941 1.45820941 1.45820941
#  1.45820941 1.45820941 1.45820941 1.45820941 1.45820941 1.45820941
#  1.45820941 1.45820941 1.45820941 1.45820941 1.45820941 1.45820941
#  1.45820941 1.45820941 1.45820941 1.45820941]

# %% [markdown]
# # Predicting Values for X_train using local weights

# %%
X_test = [3.5, 5, 6, 8, 10]
# Out:
# Unexpected exception formatting exception. Falling back to standard exception
# Traceback (most recent call last):
#   File "C:\Users\amber\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\IPython\core\interactiveshell.py", line 3398, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\amber\AppData\Local\Temp\ipykernel_20372\1626951310.py", line 2, in <cell line: 2>
#     ok.locallyWeighted(X_train,Y_train,X_test,0.2,100)
#   File "C:\Users\amber\OneDrive\Desktop\210117_AmberSingh\assignment1\linearRegression.py", line 65, in locallyWeighted
#     for i in range(num_iters):
# ValueError: operands could not be broadcast together with shapes (6,) (5,)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\amber\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\IPython\core\interactiveshell.py", line 1993, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(
#   File "C:\Users\amber\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\IPython\core\ultratb.py", line 1118, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "C:\Users\amber\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\IPython\core\ultratb.py", line 1012, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "C:\Users\amber\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\IPython\core\ultratb.py", line 865, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#   File "C:\Users\amber\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\IPython\core\ultratb.py", line 818, in format_exception_as_a_whole
#     frames.append(self.format_record(r))
#   File "C:\Users\amber\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\IPython\core\ultratb.py", line 736, in format_record
#     result += ''.join(_format_traceback_lines(frame_info.lines, Colors, self.has_colors, lvals))
#   File "C:\Users\amber\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\stack_data\utils.py", line 145, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#   File "C:\Users\amber\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\stack_data\core.py", line 698, in lines
#     pieces = self.included_pieces
#   File "C:\Users\amber\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\stack_data\utils.py", line 145, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#   File "C:\Users\amber\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\stack_data\core.py", line 649, in included_pieces
#     pos = scope_pieces.index(self.executing_piece)
#   File "C:\Users\amber\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\stack_data\utils.py", line 145, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#   File "C:\Users\amber\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\stack_data\core.py", line 628, in executing_piece
#     return only(
#   File "C:\Users\amber\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\executing\executing.py", line 164, in only
#     raise NotOneValueFound('Expected one value, found 0')
# executing.executing.NotOneValueFound: Expected one value, found 0
