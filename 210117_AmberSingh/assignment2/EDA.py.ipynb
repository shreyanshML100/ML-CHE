# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler  
import linearRegression as lr

# %%
df=pd.read_excel('AirQualityUCI.xlsx')

# %%
df.head()
# Out:
#         Date      Time  CO(GT)  PT08.S1(CO)  NMHC(GT)   C6H6(GT)  \
# 0 2004-03-10  18:00:00     2.6      1360.00       150  11.881723
# 1 2004-03-10  19:00:00     2.0      1292.25       112   9.397165
# 2 2004-03-10  20:00:00     2.2      1402.00        88   8.997817
# 3 2004-03-10  21:00:00     2.2      1375.50        80   9.228796
# 4 2004-03-10  22:00:00     1.6      1272.25        51   6.518224
#
#    PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)  \
# 0        1045.50    166.0       1056.25    113.0       1692.00      1267.50
# 1         954.75    103.0       1173.75     92.0       1558.75       972.25
# 2         939.25    131.0       1140.00    114.0       1554.50      1074.00
# 3         948.25    172.0       1092.00    122.0       1583.75      1203.25
# 4         835.50    131.0       1205.00    116.0       1490.00      1110.00
#
#        T         RH        AH
# 0  13.60  48.875001  0.757754
# 1  13.30  47.700000  0.725487
# 2  11.90  53.975000  0.750239
# 3  11.00  60.000000  0.786713
# 4  11.15  59.575001  0.788794

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9357 entries, 0 to 9356
# Data columns (total 15 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date           9357 non-null   datetime64[ns]
#  1   Time           9357 non-null   object
#  2   CO(GT)         9357 non-null   float64
#  3   PT08.S1(CO)    9357 non-null   float64
#  4   NMHC(GT)       9357 non-null   int64
#  5   C6H6(GT)       9357 non-null   float64
#  6   PT08.S2(NMHC)  9357 non-null   float64
#  7   NOx(GT)        9357 non-null   float64
#  8   PT08.S3(NOx)   9357 non-null   float64
#  9   NO2(GT)        9357 non-null   float64
#  10  PT08.S4(NO2)   9357 non-null   float64
#  11  PT08.S5(O3)    9357 non-null   float64
#  12  T              9357 non-null   float64
#  13  RH             9357 non-null   float64
#  14  AH             9357 non-null   float64
# dtypes: datetime64[ns](1), float64(12), int64(1), object(1)
# memory usage: 1.1+ MB

# %%
df.shape
# Out:
# (9357, 15)

# %%
df.describe()
# Out:
#             CO(GT)  PT08.S1(CO)     NMHC(GT)     C6H6(GT)  PT08.S2(NMHC)  \
# count  9357.000000  9357.000000  9357.000000  9357.000000    9357.000000
# mean    -34.207524  1048.869652  -159.090093     1.865576     894.475963
# std      77.657170   329.817015   139.789093    41.380154     342.315902
# min    -200.000000  -200.000000  -200.000000  -200.000000    -200.000000
# 25%       0.600000   921.000000  -200.000000     4.004958     711.000000
# 50%       1.500000  1052.500000  -200.000000     7.886653     894.500000
# 75%       2.600000  1221.250000  -200.000000    13.636091    1104.750000
# max      11.900000  2039.750000  1189.000000    63.741476    2214.000000
#
#            NOx(GT)  PT08.S3(NOx)      NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)  \
# count  9357.000000   9357.000000  9357.000000   9357.000000  9357.000000
# mean    168.604200    794.872333    58.135898   1391.363266   974.951534
# std     257.424561    321.977031   126.931428    467.192382   456.922728
# min    -200.000000   -200.000000  -200.000000   -200.000000  -200.000000
# 25%      50.000000    637.000000    53.000000   1184.750000   699.750000
# 50%     141.000000    794.250000    96.000000   1445.500000   942.000000
# 75%     284.200000    960.250000   133.000000   1662.000000  1255.250000
# max    1479.000000   2682.750000   339.700000   2775.000000  2522.750000
#
#                  T           RH           AH
# count  9357.000000  9357.000000  9357.000000
# mean      9.776600    39.483611    -6.837604
# std      43.203438    51.215645    38.976670
# min    -200.000000  -200.000000  -200.000000
# 25%      10.950000    34.050000     0.692275
# 50%      17.200000    48.550000     0.976823
# 75%      24.075000    61.875000     1.296223
# max      44.600000    88.725000     2.231036

# %%
df['Date']=pd.to_datetime(df['Date'],format='%y-%m-%d')

# %%
df['Month']=df['Date'].dt.month_name()
df.head()
# Out:
#         Date      Time  CO(GT)  PT08.S1(CO)  NMHC(GT)   C6H6(GT)  \
# 0 2004-03-10  18:00:00     2.6      1360.00       150  11.881723
# 1 2004-03-10  19:00:00     2.0      1292.25       112   9.397165
# 2 2004-03-10  20:00:00     2.2      1402.00        88   8.997817
# 3 2004-03-10  21:00:00     2.2      1375.50        80   9.228796
# 4 2004-03-10  22:00:00     1.6      1272.25        51   6.518224
#
#    PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)  \
# 0        1045.50    166.0       1056.25    113.0       1692.00      1267.50
# 1         954.75    103.0       1173.75     92.0       1558.75       972.25
# 2         939.25    131.0       1140.00    114.0       1554.50      1074.00
# 3         948.25    172.0       1092.00    122.0       1583.75      1203.25
# 4         835.50    131.0       1205.00    116.0       1490.00      1110.00
#
#        T         RH        AH  Month
# 0  13.60  48.875001  0.757754  March
# 1  13.30  47.700000  0.725487  March
# 2  11.90  53.975000  0.750239  March
# 3  11.00  60.000000  0.786713  March
# 4  11.15  59.575001  0.788794  March

# %%
df['Time'] = pd.to_datetime(df['Time'],format= '%H:%M:%S').dt.hour

# %%
df.head()
# Out:
#         Date  Time  CO(GT)  PT08.S1(CO)  NMHC(GT)   C6H6(GT)  PT08.S2(NMHC)  \
# 0 2004-03-10    18     2.6      1360.00       150  11.881723        1045.50
# 1 2004-03-10    19     2.0      1292.25       112   9.397165         954.75
# 2 2004-03-10    20     2.2      1402.00        88   8.997817         939.25
# 3 2004-03-10    21     2.2      1375.50        80   9.228796         948.25
# 4 2004-03-10    22     1.6      1272.25        51   6.518224         835.50
#
#    NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)      T  \
# 0    166.0       1056.25    113.0       1692.00      1267.50  13.60
# 1    103.0       1173.75     92.0       1558.75       972.25  13.30
# 2    131.0       1140.00    114.0       1554.50      1074.00  11.90
# 3    172.0       1092.00    122.0       1583.75      1203.25  11.00
# 4    131.0       1205.00    116.0       1490.00      1110.00  11.15
#
#           RH        AH  Month
# 0  48.875001  0.757754  March
# 1  47.700000  0.725487  March
# 2  53.975000  0.750239  March
# 3  60.000000  0.786713  March
# 4  59.575001  0.788794  March

# %%
plt.figure(figsize=(9,9))
sns.heatmap(df.corr(), annot=True, linewidths=.30)
# Out:
# <AxesSubplot: >

# %%
df.info() #notice datatype of time is changed!
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9357 entries, 0 to 9356
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date           9357 non-null   datetime64[ns]
#  1   Time           9357 non-null   int64
#  2   CO(GT)         9357 non-null   float64
#  3   PT08.S1(CO)    9357 non-null   float64
#  4   NMHC(GT)       9357 non-null   int64
#  5   C6H6(GT)       9357 non-null   float64
#  6   PT08.S2(NMHC)  9357 non-null   float64
#  7   NOx(GT)        9357 non-null   float64
#  8   PT08.S3(NOx)   9357 non-null   float64
#  9   NO2(GT)        9357 non-null   float64
#  10  PT08.S4(NO2)   9357 non-null   float64
#  11  PT08.S5(O3)    9357 non-null   float64
#  12  T              9357 non-null   float64
#  13  RH             9357 non-null   float64
#  14  AH             9357 non-null   float64
#  15  Month          9357 non-null   object
# dtypes: datetime64[ns](1), float64(12), int64(2), object(1)
# memory usage: 1.1+ MB

# %%
col_=df.columns.tolist()[1:]
X=df[col_].drop('RH',axis=1).drop('Month',axis=1)
y=df['RH']

# %%
ss=StandardScaler() 
X_std=ss.fit_transform(X) 
X_train, X_test, y_train, y_test=train_test_split(X_std,y,test_size=0.1, random_state=42)
print('The Training data size is ',X_train.shape)
print('The Test data size is ',X_test.shape)
# Out:
# The Training data size is  (8421, 13)
# The Test data size is  (936, 13)

# %%
y_train=y_train.to_numpy()
y_test=y_test.to_numpy()

# %%
theta=lr.fitGD(X_train,y_train,0.001,0,0,2000)
print(theta)
# Out:
# Number of Iterations:0
# Cost Function:2101.6253473795573
# Number of Iterations:100
# Cost Function:1237.287495145858
# Number of Iterations:200
# Cost Function:876.2030557825791
# Number of Iterations:300
# Cost Function:690.4937377698683
# Number of Iterations:400
# Cost Function:574.2226871873611
# Number of Iterations:500
# Cost Function:491.14799257709217
# Number of Iterations:600
# Cost Function:427.4689988112301
# Number of Iterations:700
# Cost Function:376.9778026790467
# Number of Iterations:800
# Cost Function:336.2813396862276
# Number of Iterations:900
# Cost Function:303.19330895994017
# Number of Iterations:1000
# Cost Function:276.1476680205974
# Number of Iterations:1100
# Cost Function:253.95573573134084
# Number of Iterations:1200
# Cost Function:235.687662770785
# Number of Iterations:1300
# Cost Function:220.60429799684468
# Number of Iterations:1400
# Cost Function:208.11269434686605
# Number of Iterations:1500
# Cost Function:197.73452704835267
# Number of Iterations:1600
# Cost Function:189.08252339900673
# Number of Iterations:1700
# Cost Function:181.84233563485787
# Number of Iterations:1800
# Cost Function:175.7583386592793
# Number of Iterations:1900
# Cost Function:170.6223686986804
# [34.15887016 -5.37779093  0.5442944   7.50542194 -1.85019713 11.25233768
#  -0.1227991   1.01221258  9.17860275 -1.63387364  0.88897795  3.83950627
#   8.41066293 13.46271845]

# %%
m,n=np.shape(X_train)
y_predict_train=np.zeros(m)
b=theta[0]
w=theta[1:]
for i in range(m):
    y_predict_train[i]=np.dot(w,X_train[i])+b
error=0
for i in range(m):
    error=error+(y_predict_train[i]-y_train[i])**2
error=error/(2*m)
print("Training Set error:{}".format(error))
# Out:
# Training Set error:166.26472195058267

# %%
tr=np.shape(X_test)[0]
y_predict_test=np.zeros(tr)
for i in range(tr):
    y_predict_test[i]=np.dot(w,X_test[i])+b
error_test=0
for i in range(tr):
    error_test=error_test+(y_predict_test[i]-y_test[i])**2
error_test=error_test/(2*tr)
print("Test Set error:{}".format(error_test))
# Out:
# Test Set error:160.8497199258397

# %%
theta_normal=lr.fitNormal(X_train,y_train)
print(theta_normal)
# Out:
# [ -0.67844806   0.21970481   3.92382343  -2.34929157 -57.76452792
#  -12.47436765   7.58115068  -5.96275906  -6.32809105  26.25469707
#   -0.73550448 -86.94925746 181.76929081]

# %%
y_predict_train_n=np.zeros(m)
for i in range(m):
    y_predict_train_n[i]=np.dot(theta_normal,X_train[i])
error_n=0
for i in range(m):
    error_n=error_n+(y_predict_train_n[i]-y_train[i])**2
error_n=error_n/(2*m)
print("Training Set error using Normal Equations:{}".format(error_n))
# Out:
# Training Set error using Normal Equations:810.0435289425654

# %%
y_predict_test_n=np.zeros(tr)
for i in range(tr):
    y_predict_test_n[i]=np.dot(theta_normal,X_test[i])
error_test_n=0
for i in range(tr):
    error_test_n=error_test_n+(y_predict_test_n[i]-y_test[i])**2
error_test_n=error_test_n/(2*tr)
print("Test Set error using Normal Equations:{}".format(error_test_n))
# Out:
# Test Set error using Normal Equations:809.0501432916673
